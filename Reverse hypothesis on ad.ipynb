# %%
print("          REVERSE ENGINEERING HYPOTHESIS IN SURF EXCEL ADS  ")
print("\n")
print("REASON FOR CHOOSING THE MOTHER WITH CHILDREN IN THE SURF EXCEL ADS ")
print("\n")
import pandas as pd
import numpy as np
from scipy import stats
surf_excel = pd.read_excel("C:/Users/PRADEEP PRIYA/Desktop/age sample.xlsx")
surf_excel.columns=["young_adult","adult","old_adult"]
from scipy.stats import f_oneway
stats.f_oneway(surf_excel.young_adult,surf_excel.adult,surf_excel.old_adult)
print("                            ANALYSING          ")
print("YOUNG ADULTS (15-20)")
print("\n")
stat1, p1_value = stats.shapiro(surf_excel.young_adult)
print('Z_value:%0.3f,p_value:%0.3f' % (stat1, p1_value))
print("p_value:",p1_value)
#Here i take commonly used confidence level that is 95%-0.05
if(p1_value > 0.05):
    print("Accept Null Hypothesis")
else:
    print("Reject Null Hypothesis")
print("\n")
print("ADULTS   (20-30)")
print("\n")
stat2, p2_value =stats.shapiro(surf_excel.adult)
print('Z_value:%0.3f,p_value:%0.3f' % (stat2, p2_value))
print("p_value:",p2_value)
#Here i take commonly used confidence level that is 95%-0.05
if(p2_value > 0.05):
    print("Accept Null Hypothesis")
else:
    print("Reject Null Hypothesis")
print("\n")
print("OLD ADULTS   (Above 30)")
print("\n")
stat3, p3_value =stats.shapiro(surf_excel.old_adult)
print('Z_value:%0.3f,p_value:%0.3f' % (stat3, p3_value))
print("p_value:",p3_value)
#Here i take commonly used confidence level that is 95%-0.05
if(p3_value > 0.05):
    print("Accept Null Hypothesis")
else:
    print("Reject Null Hypothesis")
print("                           CONCLUSION  ")
if(p1_value > p2_value and p1_value > p3_value):
    print("Young adult is best for doing ads")
if(p2_value > p1_value and p2_value > p3_value):
    print("Adult is best for doing ads") 
else:
    print("Old adult is best for doing ads") 
print("\n")
print("          OVERALL ANALYSIS OF THE SURF EXCEL ADS ")
print("\n")
print("          REVERSE ENGINEERING HYPOTHESIS IN SURF EXCEL ADS  ")
print("\n")
import pandas as pd
import numpy as np
surf_excel1 = pd.read_excel("C:/Users/PRADEEP PRIYA/Desktop/surfexcel_buy.xlsx")
product_data=pd.crosstab(surf_excel1.person,surf_excel1.surfexcel)
print(product_data)
import matplotlib.pyplot as plt
from statsmodels.stats.proportion import proportions_ztest
count=np.array([97,43])
nobs=np.array([125,125])
stat, p_value = proportions_ztest(count=138,nobs=250,value=0.55)
#count= no of successes-In this family with children purchased surfexcel 97 out of 150
# and family without children purchased surfexcel 43 out of 150
#nobs=no of trials- total no of trials=250
#value=hypothesized population proportion-(138/250)*100 = That is 0.55
print("\n")
print("                            ANALYSING          ")
print("\n")
print('Z_value:%0.3f,p_value:%0.3f' % (stat, p_value))
print("p_value:",p_value)
#Here i take commonly used confidence level that is 95%-0.05
if(p_value > 0.05):
    print("Accept Null Hypothesis")
else:
    print("Reject Null Hypothesis")
print("                           CONCLUSION       ")
print("\n")
print("There is no difference in purchasing the product because of the ads")
# BECAUSE WE CANOT SAY FAMILY WITH CHILDREN ALWAYS BUY THIS PRODUCT
# AND FAMILY WITHOUT CHILDREN WILL NOT BUY THIS PRODUCT.
# NOT ONLY BY SEEING THE ADS FAMILY WITH CHILDREN WILL PURCHASED THIS PRODUCTS 
# BUT ALSO PEOPLE PURCHASED THIS PRODUCT BECAUSE OF THE BRAND,
# QUALITY,PACKAGE, AND PRICE.
# MORE OVER THE MAIN TARGET OF THE ADS WHICH SHOWN IN SOCIAL MEDIA IS ACHIEVING SUCCESSFULLY.
# THEIR TARGET IDEA TO INTERACT THE PEOPLE IS WELL AND GOOD.
# Out:
#           REVERSE ENGINEERING HYPOTHESIS IN SURF EXCEL ADS
#
#
# REASON FOR CHOOSING THE MOTHER WITH CHILDREN IN THE SURF EXCEL ADS
#
#
#                             ANALYSING
# YOUNG ADULTS (15-20)
#
#
# Z_value:0.734,p_value:0.021
# p_value: 0.02112302929162979
# Reject Null Hypothesis
#
#
# ADULTS   (20-30)
#
#
# Z_value:0.944,p_value:0.691
# p_value: 0.6911060810089111
# Accept Null Hypothesis
#
#
# OLD ADULTS   (Above 30)
#
#
# Z_value:0.883,p_value:0.321
# p_value: 0.32105153799057007
# Accept Null Hypothesis
#                            CONCLUSION
# Adult is best for doing ads
#
#
#           OVERALL ANALYSIS OF THE SURF EXCEL ADS
#
#
#           REVERSE ENGINEERING HYPOTHESIS IN SURF EXCEL ADS
#
#
# surfexcel                buy  not buy
# person
# family with children      97       28
# family without children   40       85
#
#
#                             ANALYSING
#
#
# Z_value:0.064,p_value:0.949
# p_value: 0.9492963879337732
# Accept Null Hypothesis
# ...
